# %%
# Copyright (c) Microsoft Corporation.
# Licensed under the MIT License.

# %% [markdown]
# # Node Classification with GAT

# %%
from deepgnn.graph_engine.data.cora import CoraFull
CoraFull("/tmp/cora/")
# Out:
# [2022-02-15 10:07:20,542] {convert.py:200} INFO - worker 0 try to generate partition: 0 - 1
# [2022-02-15 10:07:20,545] {_adl_reader.py:123} INFO - [1,0] Input files: ['/tmp/cora/graph.json']
# [2022-02-15 10:07:20,896] {dispatcher.py:126} INFO - record processed: 1000
# [2022-02-15 10:07:21,176] {dispatcher.py:126} INFO - record processed: 2000
# /home/tiantiaw/.local/lib/python3.6/site-packages/deepgnn/graph_engine/snark/alias.py:19: RuntimeWarning: invalid value encountered in true_divide
#   weights = np.multiply(weights, len(weights) / np.sum(weights))
# [2022-02-15 10:07:21,441] {local.py:30} INFO - Graph data path: /tmp/cora/. Partitions [0]
# [2022-02-15 10:07:21,456] {local.py:35} INFO - Loaded snark graph. Node counts: [2708, 0]. Edge counts: [0, 0]

# %%
import argparse
import numpy as np
import tensorflow as tf
from dataclasses import dataclass
from typing import Dict, List, Union, Callable, Any, Tuple
from contextlib import closing
from deepgnn import str2list_int, setup_default_logging_config
from deepgnn.graph_engine import Graph, FeatureType, graph_ops
from deepgnn.graph_engine import (
    SamplingStrategy,
    GENodeSampler,
    RangeNodeSampler,
    FileNodeSampler,
    BackendOptions,
    create_backend,
)
from deepgnn.tf import common
from deepgnn.tf.nn.gat_conv import GATConv
from deepgnn.tf.nn.metrics import masked_accuracy, masked_softmax_cross_entropy
from deepgnn.tf.common.dataset import create_tf_dataset, get_distributed_dataset
from deepgnn.tf.common.trainer_factory import get_trainer

# %%
@dataclass
class GATQueryParameter:
    neighbor_edge_types: np.array
    feature_idx: int
    feature_dim: int
    label_idx: int
    label_dim: int
    feature_type: FeatureType = FeatureType.FLOAT
    label_type: FeatureType = FeatureType.FLOAT
    num_hops: int = 2


class GATQuery:
    """Graph Query: get sub graph for GAT training"""

    def __init__(self, param: GATQueryParameter):
        self.param = param
        self.label_meta = np.array([[param.label_idx, param.label_dim]], np.int32)
        self.feat_meta = np.array([[param.feature_idx, param.feature_dim]], np.int32)

    def query_training(
        self, graph: Graph, inputs: np.array, return_shape: bool = False
    ):
        nodes, edges, src_idx = graph_ops.sub_graph(
            graph=graph,
            src_nodes=inputs,
            edge_types=self.param.neighbor_edge_types,
            num_hops=self.param.num_hops,
            self_loop=True,
            undirected=True,
            return_edges=True,
        )
        input_mask = np.zeros(nodes.size, np.bool)
        input_mask[src_idx] = True

        feat = graph.node_features(nodes, self.feat_meta, self.param.feature_type)
        label = graph.node_features(nodes, self.label_meta, self.param.label_type)
        label = label.astype(np.int32)

        edges_value = np.ones(edges.shape[0], np.float32)
        adj_shape = np.array([nodes.size, nodes.size], np.int64)
        graph_tensor = (nodes, feat, input_mask, label, edges, edges_value, adj_shape)
        if return_shape:
            # fmt: off
            # N is the number of `nodes`, which is variable because `inputs` nodes are different.
            N = None
            shapes = (
                [N],                            # Nodes
                [N, self.param.feature_dim],    # feat
                [N],                            # input_mask
                [N, self.param.label_dim],      # label
                [None, 2],                      # edges
                [None],                         # edges_value
                [2]                             # adj_shape
            )
            # fmt: on
            return graph_tensor, shapes

        return graph_tensor

# %%
class GAT(tf.keras.Model):
    """ GAT Model (supervised)"""

    def __init__(
        self,
        head_num: List[int] = [8, 1],
        hidden_dim: int = 8,
        num_classes: int = -1,
        ffd_drop: float = 0.0,
        attn_drop: float = 0.0,
        l2_coef: float = 0.0005,
    ):
        super().__init__()
        self.num_classes = num_classes
        self.l2_coef = l2_coef

        self.out_dim = num_classes

        self.input_layer = GATConv(
            attn_heads=head_num[0],
            out_dim=hidden_dim,
            act=tf.nn.elu,
            in_drop=ffd_drop,
            coef_drop=attn_drop,
            attn_aggregate="concat",
        )
        ## TODO: support hidden layer
        assert len(head_num) == 2
        self.out_layer = GATConv(
            attn_heads=head_num[1],
            out_dim=self.out_dim,
            act=None,
            in_drop=ffd_drop,
            coef_drop=attn_drop,
            attn_aggregate="average",
        )

    def forward(self, feat, bias_mat, training):
        h_1 = self.input_layer([feat, bias_mat], training=training)
        out = self.out_layer([h_1, bias_mat], training=training)
        #tf.compat.v1.logging.info("h_1 {}, out shape {}".format(h_1.shape, out.shape))
        return out

    def call(self, inputs, training=True):
        # inputs: nodes    feat      mask    labels   edges       edges_value  adj_shape
        # shape:  [N]      [N, F]    [N]     [N]      [num_e, 2]  [num_e]      [2]
        nodes, feat, mask, labels, edges, edges_value, adj_shape = inputs

        # bias_mat = -1e9 * (1.0 - adj)
        sp_adj = tf.SparseTensor(edges, edges_value, adj_shape)
        logits = self.forward(feat, sp_adj, training)

        ## embedding results
        self.src_emb = tf.boolean_mask(logits, mask)
        self.src_nodes = tf.boolean_mask(nodes, mask)

        labels = tf.one_hot(labels, self.num_classes)
        logits = tf.reshape(logits, [-1, self.num_classes])
        labels = tf.reshape(labels, [-1, self.num_classes])
        mask = tf.reshape(mask, [-1])

        ## loss
        xent_loss = masked_softmax_cross_entropy(logits, labels, mask)
        loss = xent_loss + self.l2_loss()

        ## metric
        acc = masked_accuracy(logits, labels, mask)
        return logits, loss, {"accuracy": acc}

    def l2_loss(self):
        vs = []
        for v in self.trainable_variables:
            vs.append(tf.nn.l2_loss(v))
        lossL2 = tf.add_n(vs) * self.l2_coef
        return lossL2

    def train_step(self, data: dict):
        """override base train_step."""
        with tf.GradientTape() as tape:
            _, loss, metrics = self(data, training=True)

        grads = tape.gradient(loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.trainable_variables))
        result = {"loss": loss}
        result.update(metrics)
        return result

    def test_step(self, data: dict):
        """override base test_step."""
        _, loss, metrics = self(data, training=False)
        result = {"loss": loss}
        result.update(metrics)
        return result

    def predict_step(self, data: dict):
        """override base predict_step."""
        self(data, training=False)
        return [self.src_nodes, self.src_emb]

# %%
def build_model(param):
    p = GATQueryParameter(
        neighbor_edge_types=np.array(param.neighbor_edge_types, np.int32),
        feature_idx=param.feature_idx,
        feature_dim=param.feature_dim,
        label_idx=param.label_idx,
        label_dim=param.label_dim,
        num_hops=len(param.head_num),
    )
    query_obj = GATQuery(p)

    model = GAT(
        head_num=param.head_num,
        hidden_dim=param.hidden_dim,
        num_classes=param.num_classes,
        ffd_drop=param.ffd_drop,
        attn_drop=param.attn_drop,
        l2_coef=param.l2_coef,
    )

    return model, query_obj

# %%
# fmt: off
def define_param_gat(parser):
    parser.add_argument("--batch_size", type=int, default=16, help="mini-batch size")
    parser.add_argument("--epochs", type=int, default=200, help="num of epochs for training")
    parser.add_argument("--learning_rate", type=float, default=0.005, help="learning rate")

    ## GAT Model Parameters.
    parser.add_argument("--head_num", type=str2list_int, default="8,1", help="the number of attention headers.")
    parser.add_argument("--hidden_dim", type=int, default=8, help="hidden layer dimension.")
    parser.add_argument("--num_classes", type=int, default=-1, help="number of classes for category")
    parser.add_argument("--ffd_drop", type=float, default=0.0, help="feature dropout rate.")
    parser.add_argument("--attn_drop", type=float, default=0.0, help="attention layer dropout rate.")
    parser.add_argument("--l2_coef", type=float, default=0.0005, help="l2 loss")

    ## training node types.
    parser.add_argument("--node_types", type=str2list_int, default="0", help="Graph Node for training.")
    ## evaluate node files.
    parser.add_argument("--evaluate_node_files", type=str, help="evaluate node file list.")
    ## inference node id
    parser.add_argument("--inf_min_id", type=int, default=0, help="inferece min node id.")
    parser.add_argument("--inf_max_id", type=int, default=-1, help="inference max node id.")

    parser.add_argument(
        "--distributed_strategy",
        type=str,
        default=None,
        choices=[None, "Mirrored", "MultiWorkerMirrored"],
        help="Distributed strategies to use.",
    )

    def register_gat_query_param(parser):
        group = parser.add_argument_group("GAT Query Parameters")
        group.add_argument("--neighbor_edge_types", type=str2list_int, default="0", help="Graph Edge for attention encoder.",)
        group.add_argument("--feature_idx", type=int, default=0, help="feature index.")
        group.add_argument("--feature_dim", type=int, default=16, help="feature dim.")
        group.add_argument("--label_idx", type=int, default=1, help="label index.")
        group.add_argument("--label_dim", type=int, default=1, help="label dim.")

    register_gat_query_param(parser)
# fmt: on

# %%
def run_train(param, trainer, query, model, tf1_mode, backend):
    tf_dataset, steps_per_epoch = create_tf_dataset(
        sampler_class=GENodeSampler,
        query_fn=query.query_training,
        backend=backend,
        node_types=np.array(param.node_types, dtype=np.int32),
        batch_size=param.batch_size,
        num_workers=trainer.worker_size,
        worker_index=trainer.task_index,
        strategy=SamplingStrategy.RandomWithoutReplacement,
    )

    distributed_dataset = get_distributed_dataset(
        # NOTE: here we flatten all the epochs into 1 to increase performance.
        lambda ctx: tf_dataset.repeat(param.epochs)
    )

    # we need to make sure the steps_per_epoch are provided in distributed dataset.
    assert steps_per_epoch is not None or param.steps_per_epoch is not None
    # Since we flatten the dataset to len(dataset) * param.epochs,
    # we alos need to update steps_per_epoch.
    steps_per_epoch = param.epochs * (steps_per_epoch or param.steps_per_epoch)

    if tf1_mode:
        opt = tf.compat.v1.train.AdamOptimizer(param.learning_rate * trainer.lr_scaler)
    else:
        opt = tf.keras.optimizers.Adam(
            learning_rate=param.learning_rate * trainer.lr_scaler
        )

    trainer.train(
        dataset=distributed_dataset,
        model=model,
        optimizer=opt,
        epochs=1,
        steps_per_epoch=steps_per_epoch,
    )

# %%
try:
    define_param_base
except NameError:
    define_param_base = define_param_gat

# %%
# Not needed for .py file runs
MODEL_DIR = f"tmp/gat_{np.random.randint(9999999)}"
arg_list = [
    "--data_dir", "/tmp/cora",
    "--mode", "train",
    # "--trainer", "hvd",
    "--seed", "123",
    "--eager",
    "--log_save_steps", "1",
    "--backend", "snark",
    "--graph_type", "local",
    "--converter", "skip",
#    "--sample_file", "/tmp/cora/train.nodes",
#    "--node_type", "0",
    "--neighbor_edge_types", "0",
    "--feature_idx", "0",
    "--feature_dim", "1433",
    "--label_idx", "1",
    "--label_dim", "1",
    "--num_classes", "7",
    "--batch_size", "140",
    "--epochs", "50",
    "--learning_rate", "0.005",
    "--l2_coef", "0.0005",
    "--attn_drop", "0.6",
    "--ffd_drop", "0.6",
    "--head_num", "8,1",
    "--hidden_dim", "8",
    "--model_dir", MODEL_DIR,
#    "--metric_dir", MODEL_DIR,
#    "--save_path", MODEL_DIR,
]

def define_param_wrap(define_param):
    def define_param_new(parser):
        define_param(parser)
        parse_args = parser.parse_args
        parser.parse_args = lambda: parse_args(arg_list)
    return define_param_new

define_param_gat = define_param_wrap(define_param_base)

# %%
def _main():
    # setup default logging component.
    setup_default_logging_config(enable_telemetry=True)

    parser = argparse.ArgumentParser(
        formatter_class=argparse.ArgumentDefaultsHelpFormatter, allow_abbrev=False
    )
    common.args.import_default_parameters(parser)
    define_param_gat(parser)

    param = parser.parse_args()
    common.args.log_all_parameters(param)

    trainer = get_trainer(param)

    backend = create_backend(BackendOptions(param), is_leader=(trainer.task_index == 0))

    def run(tf1_mode=False):
        model, query = build_model(param)
        if param.mode == common.args.TrainMode.TRAIN:
            run_train(param, trainer, query, model, tf1_mode, backend)
        elif param.mode == common.args.TrainMode.EVALUATE:
            run_eval(param, trainer, query, model, backend)
        elif param.mode == common.args.TrainMode.INFERENCE:
            run_inference(param, trainer, query, model, backend)

    with closing(backend):
        if param.eager:
            strategy = None
            if param.distributed_strategy == "Default":
                strategy = tf.distribute.get_strategy()
            elif param.distributed_strategy == "Mirrored":
                strategy = tf.distribute.MirroredStrategy()
            elif param.distributed_strategy == "MultiWorkerMirrored":
                strategy = tf.distribute.MultiWorkerMirroredStrategy()

            if strategy:
                with strategy.scope():
                    run()
            else:
                run()
        else:
            with tf.Graph().as_default():
                trainer.set_random_seed(param.seed)
                with trainer.tf_device():
                    run(tf1_mode=True)


_main()
# Out:
# [2022-02-15 10:07:25,733] {args.py:13} INFO - mode:	train
# [2022-02-15 10:07:25,735] {args.py:13} INFO - user_name:	tiantiaw
# [2022-02-15 10:07:25,736] {args.py:13} INFO - model_dir:	tmp/gat_9313790
# [2022-02-15 10:07:25,737] {args.py:13} INFO - trainer:	ps
# [2022-02-15 10:07:25,738] {args.py:13} INFO - eager:	True
# [2022-02-15 10:07:25,739] {args.py:13} INFO - job_id:	c128c89d
# [2022-02-15 10:07:25,740] {args.py:13} INFO - seed:	123
# [2022-02-15 10:07:25,741] {args.py:13} INFO - gpu:	False
# [2022-02-15 10:07:25,741] {args.py:13} INFO - partitions:	[0]
# [2022-02-15 10:07:25,746] {args.py:13} INFO - steps_per_epoch:	None
# [2022-02-15 10:07:25,747] {args.py:13} INFO - job_name:	None
# [2022-02-15 10:07:25,749] {args.py:13} INFO - task_index:	0
# [2022-02-15 10:07:25,750] {args.py:13} INFO - ps_hosts:	['']
# [2022-02-15 10:07:25,751] {args.py:13} INFO - worker_hosts:	['']
# [2022-02-15 10:07:25,753] {args.py:13} INFO - graph_type:	local
# [2022-02-15 10:07:25,753] {args.py:13} INFO - data_dir:	/tmp/cora
# [2022-02-15 10:07:25,754] {args.py:13} INFO - enable_ssl:	False
# [2022-02-15 10:07:25,755] {args.py:13} INFO - ssl_cert:
# [2022-02-15 10:07:25,756] {args.py:13} INFO - backend:	snark
# [2022-02-15 10:07:25,757] {args.py:13} INFO - servers:
# [2022-02-15 10:07:25,759] {args.py:13} INFO - converter:	skip
# [2022-02-15 10:07:25,761] {args.py:13} INFO - num_ge:	0
# [2022-02-15 10:07:25,762] {args.py:13} INFO - ge_start_timeout:	30
# [2022-02-15 10:07:25,762] {args.py:13} INFO - GE_OMP_NUM_THREADS:	1
# [2022-02-15 10:07:25,764] {args.py:13} INFO - server_idx:	None
# [2022-02-15 10:07:25,765] {args.py:13} INFO - client_rank:	None
# [2022-02-15 10:07:25,773] {args.py:13} INFO - skip_ge_start:	False
# [2022-02-15 10:07:25,774] {args.py:13} INFO - sync_dir:
# [2022-02-15 10:07:25,776] {args.py:13} INFO - prefetch_queue_size:	16
# [2022-02-15 10:07:25,777] {args.py:13} INFO - prefetch_worker_size:	2
# [2022-02-15 10:07:25,778] {args.py:13} INFO - checkpoint_save_secs:	3600
# [2022-02-15 10:07:25,780] {args.py:13} INFO - profiler_save_secs:	180
# [2022-02-15 10:07:25,781] {args.py:13} INFO - log_save_steps:	1
# [2022-02-15 10:07:25,782] {args.py:13} INFO - summary_save_steps:	100
# [2022-02-15 10:07:25,783] {args.py:13} INFO - profile_batch:	[100, 110]
# [2022-02-15 10:07:25,785] {args.py:13} INFO - batch_size:	140
# [2022-02-15 10:07:25,786] {args.py:13} INFO - epochs:	50
# [2022-02-15 10:07:25,787] {args.py:13} INFO - learning_rate:	0.005
# [2022-02-15 10:07:25,788] {args.py:13} INFO - head_num:	[8, 1]
# [2022-02-15 10:07:25,794] {args.py:13} INFO - hidden_dim:	8
# [2022-02-15 10:07:25,795] {args.py:13} INFO - num_classes:	7
# [2022-02-15 10:07:25,796] {args.py:13} INFO - ffd_drop:	0.6
# [2022-02-15 10:07:25,798] {args.py:13} INFO - attn_drop:	0.6
# [2022-02-15 10:07:25,799] {args.py:13} INFO - l2_coef:	0.0005
# [2022-02-15 10:07:25,800] {args.py:13} INFO - node_types:	[0]
# [2022-02-15 10:07:25,801] {args.py:13} INFO - evaluate_node_files:	None
# [2022-02-15 10:07:25,803] {args.py:13} INFO - inf_min_id:	0
# [2022-02-15 10:07:25,804] {args.py:13} INFO - inf_max_id:	-1
# [2022-02-15 10:07:25,805] {args.py:13} INFO - distributed_strategy:	None
# [2022-02-15 10:07:25,812] {args.py:13} INFO - neighbor_edge_types:	[0]
# [2022-02-15 10:07:25,814] {args.py:13} INFO - feature_idx:	0
# [2022-02-15 10:07:25,815] {args.py:13} INFO - feature_dim:	1433
# [2022-02-15 10:07:25,816] {args.py:13} INFO - label_idx:	1
# [2022-02-15 10:07:25,818] {args.py:13} INFO - label_dim:	1
# [2022-02-15 10:07:25,848] {base_trainer.py:42} INFO - tensorflow version: 2.5.0
# [2022-02-15 10:07:26,041] {tf2_trainer.py:137} INFO - device: PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')
# [2022-02-15 10:07:26,048] {local.py:30} INFO - Graph data path: /tmp/cora. Partitions [0]
# [2022-02-15 10:07:26,070] {local.py:35} INFO - Loaded snark graph. Node counts: [2708, 0]. Edge counts: [0, 0]
# [2022-02-15 10:07:26,331] {samplers.py:148} INFO - Node Count ([0]): 2708
# [2022-02-15 10:07:26,337] {dataset.py:33} INFO - check array shape: (140,) vs [None]
# [2022-02-15 10:07:26,338] {dataset.py:33} INFO - check array shape: (140, 1433) vs [None, 1433]
# [2022-02-15 10:07:26,340] {dataset.py:33} INFO - check array shape: (140,) vs [None]
# [2022-02-15 10:07:26,341] {dataset.py:33} INFO - check array shape: (140, 1) vs [None, 1]
# [2022-02-15 10:07:26,342] {dataset.py:33} INFO - check array shape: (140, 2) vs [None, 2]
# [2022-02-15 10:07:26,344] {dataset.py:33} INFO - check array shape: (140,) vs [None]
# [2022-02-15 10:07:26,344] {dataset.py:33} INFO - check array shape: (2,) vs [2]
# [2022-02-15 10:07:26,346] {dataset.py:25} INFO - numpy ((140,), int64), tf tensor ((140,), <dtype: 'int64'>)
# [2022-02-15 10:07:26,348] {dataset.py:25} INFO - numpy ((140, 1433), float32), tf tensor ((140, 1433), <dtype: 'float32'>)
# [2022-02-15 10:07:26,349] {dataset.py:25} INFO - numpy ((140,), bool), tf tensor ((140,), <dtype: 'bool'>)
# [2022-02-15 10:07:26,350] {dataset.py:25} INFO - numpy ((140, 1), int32), tf tensor ((140, 1), <dtype: 'int32'>)
# [2022-02-15 10:07:26,351] {dataset.py:25} INFO - numpy ((140, 2), int64), tf tensor ((140, 2), <dtype: 'int64'>)
# [2022-02-15 10:07:26,351] {dataset.py:25} INFO - numpy ((140,), float32), tf tensor ((140,), <dtype: 'float32'>)
# [2022-02-15 10:07:26,352] {dataset.py:25} INFO - numpy ((2,), int64), tf tensor ((2,), <dtype: 'int64'>)
# [2022-02-15 10:07:26,545] {logging_utils.py:76} INFO - Training worker started.
# [2022-02-15 10:07:26,546] {tf2_trainer.py:180} INFO - training num_steps/epochs: 1000, num_epochs: 1
# [2022-02-15 10:07:28,183] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs (None, None), vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:28,243] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs (None, None), vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:28,294] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs (None, None), vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:28,346] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs (None, None), vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:28,411] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs (None, None), vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:28,524] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs (None, None), vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:28,636] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs (None, None), vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:28,716] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs (None, None), vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:28,780] {api.py:464} INFO - Att Header: seq(None, 64), seq_flts (None, 7), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs (None, None), vals (None, 7) ret (None, 7)
# /home/tiantiaw/.local/lib/python3.6/site-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/gat/gat_conv_1/attn_head_8/embedding_lookup/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/gat/gat_conv_1/attn_head_8/embedding_lookup/Reshape:0", shape=(None, 1), dtype=float32), dense_shape=Tensor("gradient_tape/gat/gat_conv_1/attn_head_8/embedding_lookup/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /home/tiantiaw/.local/lib/python3.6/site-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/gat/gat_conv_1/attn_head_8/embedding_lookup_1/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/gat/gat_conv_1/attn_head_8/embedding_lookup_1/Reshape:0", shape=(None, 1), dtype=float32), dense_shape=Tensor("gradient_tape/gat/gat_conv_1/attn_head_8/embedding_lookup_1/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /home/tiantiaw/.local/lib/python3.6/site-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/gat/gat_conv/attn_head/embedding_lookup/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/gat/gat_conv/attn_head/embedding_lookup/Reshape:0", shape=(None, 1), dtype=float32), dense_shape=Tensor("gradient_tape/gat/gat_conv/attn_head/embedding_lookup/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /home/tiantiaw/.local/lib/python3.6/site-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/gat/gat_conv/attn_head/embedding_lookup_1/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/gat/gat_conv/attn_head/embedding_lookup_1/Reshape:0", shape=(None, 1), dtype=float32), dense_shape=Tensor("gradient_tape/gat/gat_conv/attn_head/embedding_lookup_1/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /home/tiantiaw/.local/lib/python3.6/site-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/gat/gat_conv/attn_head_1/embedding_lookup/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/gat/gat_conv/attn_head_1/embedding_lookup/Reshape:0", shape=(None, 1), dtype=float32), dense_shape=Tensor("gradient_tape/gat/gat_conv/attn_head_1/embedding_lookup/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /home/tiantiaw/.local/lib/python3.6/site-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/gat/gat_conv/attn_head_1/embedding_lookup_1/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/gat/gat_conv/attn_head_1/embedding_lookup_1/Reshape:0", shape=(None, 1), dtype=float32), dense_shape=Tensor("gradient_tape/gat/gat_conv/attn_head_1/embedding_lookup_1/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /home/tiantiaw/.local/lib/python3.6/site-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/gat/gat_conv/attn_head_2/embedding_lookup/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/gat/gat_conv/attn_head_2/embedding_lookup/Reshape:0", shape=(None, 1), dtype=float32), dense_shape=Tensor("gradient_tape/gat/gat_conv/attn_head_2/embedding_lookup/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /home/tiantiaw/.local/lib/python3.6/site-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/gat/gat_conv/attn_head_2/embedding_lookup_1/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/gat/gat_conv/attn_head_2/embedding_lookup_1/Reshape:0", shape=(None, 1), dtype=float32), dense_shape=Tensor("gradient_tape/gat/gat_conv/attn_head_2/embedding_lookup_1/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /home/tiantiaw/.local/lib/python3.6/site-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/gat/gat_conv/attn_head_3/embedding_lookup/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/gat/gat_conv/attn_head_3/embedding_lookup/Reshape:0", shape=(None, 1), dtype=float32), dense_shape=Tensor("gradient_tape/gat/gat_conv/attn_head_3/embedding_lookup/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /home/tiantiaw/.local/lib/python3.6/site-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/gat/gat_conv/attn_head_3/embedding_lookup_1/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/gat/gat_conv/attn_head_3/embedding_lookup_1/Reshape:0", shape=(None, 1), dtype=float32), dense_shape=Tensor("gradient_tape/gat/gat_conv/attn_head_3/embedding_lookup_1/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /home/tiantiaw/.local/lib/python3.6/site-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/gat/gat_conv/attn_head_4/embedding_lookup/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/gat/gat_conv/attn_head_4/embedding_lookup/Reshape:0", shape=(None, 1), dtype=float32), dense_shape=Tensor("gradient_tape/gat/gat_conv/attn_head_4/embedding_lookup/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /home/tiantiaw/.local/lib/python3.6/site-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/gat/gat_conv/attn_head_4/embedding_lookup_1/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/gat/gat_conv/attn_head_4/embedding_lookup_1/Reshape:0", shape=(None, 1), dtype=float32), dense_shape=Tensor("gradient_tape/gat/gat_conv/attn_head_4/embedding_lookup_1/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /home/tiantiaw/.local/lib/python3.6/site-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/gat/gat_conv/attn_head_5/embedding_lookup/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/gat/gat_conv/attn_head_5/embedding_lookup/Reshape:0", shape=(None, 1), dtype=float32), dense_shape=Tensor("gradient_tape/gat/gat_conv/attn_head_5/embedding_lookup/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /home/tiantiaw/.local/lib/python3.6/site-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/gat/gat_conv/attn_head_5/embedding_lookup_1/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/gat/gat_conv/attn_head_5/embedding_lookup_1/Reshape:0", shape=(None, 1), dtype=float32), dense_shape=Tensor("gradient_tape/gat/gat_conv/attn_head_5/embedding_lookup_1/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /home/tiantiaw/.local/lib/python3.6/site-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/gat/gat_conv/attn_head_6/embedding_lookup/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/gat/gat_conv/attn_head_6/embedding_lookup/Reshape:0", shape=(None, 1), dtype=float32), dense_shape=Tensor("gradient_tape/gat/gat_conv/attn_head_6/embedding_lookup/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /home/tiantiaw/.local/lib/python3.6/site-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/gat/gat_conv/attn_head_6/embedding_lookup_1/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/gat/gat_conv/attn_head_6/embedding_lookup_1/Reshape:0", shape=(None, 1), dtype=float32), dense_shape=Tensor("gradient_tape/gat/gat_conv/attn_head_6/embedding_lookup_1/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /home/tiantiaw/.local/lib/python3.6/site-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/gat/gat_conv/attn_head_7/embedding_lookup/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/gat/gat_conv/attn_head_7/embedding_lookup/Reshape:0", shape=(None, 1), dtype=float32), dense_shape=Tensor("gradient_tape/gat/gat_conv/attn_head_7/embedding_lookup/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# /home/tiantiaw/.local/lib/python3.6/site-packages/tensorflow/python/framework/indexed_slices.py:449: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/gat/gat_conv/attn_head_7/embedding_lookup_1/Reshape_1:0", shape=(None,), dtype=int64), values=Tensor("gradient_tape/gat/gat_conv/attn_head_7/embedding_lookup_1/Reshape:0", shape=(None, 1), dtype=float32), dense_shape=Tensor("gradient_tape/gat/gat_conv/attn_head_7/embedding_lookup_1/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# [2022-02-15 10:07:31,425] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs (None, None), vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:31,512] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs (None, None), vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:31,605] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs (None, None), vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:31,702] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs (None, None), vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:31,781] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs (None, None), vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:31,843] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs (None, None), vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:31,898] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs (None, None), vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:31,960] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs (None, None), vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:32,027] {api.py:464} INFO - Att Header: seq(None, 64), seq_flts (None, 7), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs (None, None), vals (None, 7) ret (None, 7)
# [2022-02-15 10:07:36,838] {utils.py:160} INFO - --------------variables-----------
# [2022-02-15 10:07:36,842] {utils.py:162} INFO - 0	attn.bias:0	(8,)
# [2022-02-15 10:07:36,843] {utils.py:162} INFO - 1	gat/gat_conv/attn_head/w/kernel:0	(1433, 8)
# [2022-02-15 10:07:36
callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0291s vs `on_train_batch_end` time: 0.1094s). Check your callbacks.
# [2022-02-15 10:07:37,677] {tf2_trainer.py:72} INFO - train-step 6(epoch=0)  loss:2.3089, accuracy:0.2286 (0.0383 sec/step)
# [2022-02-15 10:07:37,701] {tf2_trainer.py:72} INFO - train-step 7(epoch=0)  loss:2.1230, accuracy:0.2429 (0.0237 sec/step)
# [2022-02-15 10:07:37,735] {tf2_trainer.py:72} INFO - train-step 8(epoch=0)  loss:2.1623, accuracy:0.2857 (0.0346 sec/step)
# [2022-02-15 10:07:37,769] {tf2_trainer.py:72} INFO - train-step 9(epoch=0)  loss:2.3751, accuracy:0.1857 (0.0340 sec/step)
# [2022-02-15 10:07:37,833] {tf2_trainer.py:72} INFO - train-step 10(epoch=0)  loss:2.3447, accuracy:0.2857 (0.0639 sec/step)
# [2022-02-15 10:07:37,863] {tf2_trainer.py:72} INFO - train-step 11(epoch=0)  loss:2.2962, accuracy:0.2714 (0.0292 sec/step)
# [2022-02-15 10:07:37,907] {tf2_trainer.py:72} INFO - train-step 12(epoch=0)  loss:2.3108, accuracy:0.2643 (0.0445 sec/step)
# [2022-02-15 10:07:37,966] {tf2_trainer.py:72} INFO - train-step 13(epoch=0)  loss:2.2052, accuracy:0.2286 (0.0592 sec/step)
# [2022-02-15 10:07:37,999] {tf2_trainer.py:72} INFO - train-step 14(epoch=0)  loss:2.2135, accuracy:0.2286 (0.0329 sec/step)
# [2022-02-15 10:07:38,024] {tf2_trainer.py:72} INFO - train-step 15(epoch=0)  loss:2.1724, accuracy:0.2643 (0.0250 sec/step)
# [2022-02-15 10:07:38,054] {tf2_trainer.py:72} INFO - train-step 16(epoch=0)  loss:2.1651, accuracy:0.2786 (0.0298 sec/step)
# [2022-02-15 10:07:38,074] {tf2_trainer.py:72} INFO - train-step 17(epoch=0)  loss:2.1889, accuracy:0.2857 (0.0198 sec/step)
# [2022-02-15 10:07:38,098] {tf2_trainer.py:72} INFO - train-step 18(epoch=0)  loss:2.2876, accuracy:0.2143 (0.0242 sec/step)
# [2022-02-15 10:07:38,125] {tf2_trainer.py:72} INFO - train-step 19(epoch=0)  loss:2.2458, accuracy:0.2643 (0.0271 sec/step)
# [2022-02-15 10:07:38,198] {tf2_trainer.py:72} INFO - train-step 20(epoch=0)  loss:2.1500, accuracy:0.2571 (0.0725 sec/step)
# [2022-02-15 10:07:38,232] {tf2_trainer.py:72} INFO - train-step 21(epoch=0)  loss:1.9981, accuracy:0.2786 (0.0342 sec/step)
# [2022-02-15 10:07:38,260] {tf2_trainer.py:72} INFO - train-step 22(epoch=0)  loss:2.1202, accuracy:0.3214 (0.0283 sec/step)
# [2022-02-15 10:07:38,288] {tf2_trainer.py:72} INFO - train-step 23(epoch=0)  loss:2.2040, accuracy:0.2000 (0.0281 sec/step)
# [2022-02-15 10:07:38,320] {tf2_trainer.py:72} INFO - train-step 24(epoch=0)  loss:2.1232, accuracy:0.2500 (0.0316 sec/step)
# [2022-02-15 10:07:38,350] {tf2_trainer.py:72} INFO - train-step 25(epoch=0)  loss:2.0765, accuracy:0.2357 (0.0308 sec/step)
# [2022-02-15 10:07:38,379] {tf2_trainer.py:72} INFO - train-step 26(epoch=0)  loss:2.1397, accuracy:0.2786 (0.0285 sec/step)
# [2022-02-15 10:07:38,403] {tf2_trainer.py:72} INFO - train-step 27(epoch=0)  loss:2.1030, accuracy:0.2500 (0.0244 sec/step)
# [2022-02-15 10:07:38,428] {tf2_trainer.py:72} INFO - train-step 28(epoch=0)  loss:2.1475, accuracy:0.3071 (0.0248 sec/step)
# [2022-02-15 10:07:38,466] {tf2_trainer.py:72} INFO - train-step 29(epoch=0)  loss:2.1070, accuracy:0.2643 (0.0379 sec/step)
# [2022-02-15 10:07:38,489] {tf2_trainer.py:72} INFO - train-step 30(epoch=0)  loss:2.0588, accuracy:0.2500 (0.0229 sec/step)
# [2022-02-15 10:07:38,512] {tf2_trainer.py:72} INFO - train-step 31(epoch=0)  loss:1.9850, accuracy:0.2857 (0.0232 sec/step)
# [2022-02-15 10:07:38,538] {tf2_trainer.py:72} INFO - train-step 32(epoch=0)  loss:2.0238, accuracy:0.2643 (0.0256 sec/step)
# [2022-02-15 10:07:38,560] {tf2_trainer.py:72} INFO - train-step 33(epoch=0)  loss:2.0026, accuracy:0.2857 (0.0219 sec/step)
# [2022-02-15 10:07:38,588] {tf2_trainer.py:72} INFO - train-step 34(epoch=0)  loss:1.9504, accuracy:0.3071 (0.0288 sec/step)
# [2022-02-15 10:07:38,613] {tf2_trainer.py:72} INFO - train-step 35(epoch=0)  loss:1.9606, accuracy:0.3071 (0.0243 sec/step)
# [2022-02-15 10:07:38,641] {tf2_trainer.py:72} INFO - train-step 36(epoch=0)  loss:2.0610, accuracy:0.2214 (0.0287 sec/step)
# [2022-02-15 10:07:38,669] {tf2_trainer.py:72} INFO - train-step 37(epoch=0)  loss:2.0572, accuracy:0.2857 (0.0272 sec/step)
# [2022-02-15 10:07:38,690] {tf2_trainer.py:72} INFO - train-step 38(epoch=0)  loss:2.2580, accuracy:0.2929 (0.0215 sec/step)
# [2022-02-15 10:07:38,726] {tf2_trainer.py:72} INFO - train-step 39(epoch=0)  loss:1.9862, accuracy:0.3000 (0.0359 sec/step)
# [2022-02-15 10:07:38,767] {tf2_trainer.py:72} INFO - train-step 40(epoch=0)  loss:2.0149, accuracy:0.2786 (0.0406 sec/step)
# [2022-02-15 10:07:38,798] {tf2_trainer.py:72} INFO - train-step 41(epoch=0)  loss:2.0939, accuracy:0.3143 (0.0317 sec/step)
# [2022-02-15 10:07:38,827] {tf2_trainer.py:72} INFO - train-step 42(epoch=0)  loss:1.9848, accuracy:0.3000 (0.0291 sec/step)
# [2022-02-15 10:07:38,858] {tf2_trainer.py:72} INFO - train-step 43(epoch=0)  loss:2.0207, accuracy:0.2643 (0.0309 sec/step)
# [2022-02-15 10:07:38,882] {tf2_trainer.py:72} INFO - train-step 44(epoch=0)  loss:1.9708, accuracy:0.3500 (0.0232 sec/step)
# [2022-02-15 10:07:38,919] {tf2_trainer.py:72} INFO - train-step 45(epoch=0)  loss:2.0661, accuracy:0.2786 (0.0372 sec/step)
# [2022-02-15 10:07:38,945] {tf2_trainer.py:72} INFO - train-step 46(epoch=0)  loss:2.0730, accuracy:0.2929 (0.0260 sec/step)
# [2022-02-15 10:07:38,966] {tf2_trainer.py:72} INFO - train-step 47(epoch=0)  loss:2.0082, accuracy:0.2214 (0.0212 sec/step)
# [2022-02-15 10:07:38,988] {tf2_trainer.py:72} INFO - train-step 48(epoch=0)  loss:2.0657, accuracy:0.2929 (0.0222 sec/step)
# [2022-02-15 10:07:39,027] {tf2_trainer.py:72} INFO - train-step 49(epoch=0)  loss:1.9068, accuracy:0.2857 (0.0390 sec/step)
# [2022-02-15 10:07:39,051] {tf2_trainer.py:72} INFO - train-step 50(epoch=0)  loss:2.0104, accuracy:0.3071 (0.0238 sec/step)
# [2022-02-15 10:07:39,086] {tf2_trainer.py:72} INFO - train-step 51(epoch=0)  loss:1.9306, accuracy:0.3071 (0.0350 sec/step)
# [2022-02-15 10:07:39,133] {tf2_trainer.py:72} INFO - train-step 52(epoch=0)  loss:1.9884, accuracy:0.2714 (0.0472 sec/step)
# [2022-02-15 10:07:39,210] {tf2_trainer.py:72} INFO - train-step 53(epoch=0)  loss:1.9423, accuracy:0.2786 (0.0765 sec/step)
# [2022-02-15 10:07:39,250] {tf2_trainer.py:72} INFO - train-step 54(epoch=0)  loss:2.0457, accuracy:0.2500 (0.0404 sec/step)
# [2022-02-15 10:07:39,283] {tf2_trainer.py:72} INFO - train-step 55(epoch=0)  loss:2.0047, accuracy:0.2429 (0.0327 sec/step)
# [2022-02-15 10:07:39,312] {tf2_trainer.py:72} INFO - train-step 56(epoch=0)  loss:1.9706, accuracy:0.3286 (0.0296 sec/step)
# [2022-02-15 10:07:39,329] {tf2_trainer.py:72} INFO - train-step 57(epoch=0)  loss:2.0396, accuracy:0.2500 (0.0169 sec/step)
# [2022-02-15 10:07:39,358] {tf2_trainer.py:72} INFO - train-step 58(epoch=0)  loss:1.9378, accuracy:0.2786 (0.0285 sec/step)
# [2022-02-15 10:07:39,437] {tf2_trainer.py:72} INFO - train-step 59(epoch=0)  loss:1.8817, accuracy:0.3071 (0.0789 sec/step)
# [2022-02-15 10:07:39,502] {tf2_trainer.py:72} INFO - train-step 60(epoch=0)  loss:1.9737, accuracy:0.2500 (0.0649 sec/step)
# [2022-02-15 10:07:39,556] {tf2_trainer.py:72} INFO - train-step 61(epoch=0)  loss:1.9132, accuracy:0.2571 (0.0546 sec/step)
# [2022-02-15 10:07:39,588] {tf2_trainer.py:72} INFO - train-step 62(epoch=0)  loss:1.9239, accuracy:0.2500 (0.0324 sec/step)
# [2022-02-15 10:07:39,629] {tf2_trainer.py:72} INFO - train-step 63(epoch=0)  loss:1.9264, accuracy:0.2500 (0.0405 sec/step)
# [2022-02-15 10:07:39,655] {tf2_trainer.py:72} INFO - train-step 64(epoch=0)  loss:1.9112, accuracy:0.3000 (0.0260 sec/step)
# [2022-02-15 10:07:41,224] {tf2_trainer.py:72} INFO - train-step 106(epoch=0)  loss:1.9106, accuracy:0.2929 (0.0574 sec/step)
# [2022-02-15 10:07:41,258] {tf2_trainer.py:72} INFO - train-step 107(epoch=0)  loss:1.8733, accuracy:0.3143 (0.0336 sec/step)
# [2022-02-15 10:07:41,282] {tf2_trainer.py:72} INFO - train-step 108(epoch=0)  loss:1.8953, accuracy:0.2929 (0.0246 sec/step)
# [2022-02-15 10:07:41,312] {tf2_trainer.py:72} INFO - train-step 109(epoch=0)  loss:1.9351, accuracy:0.3429 (0.0297 sec/step)
# [2022-02-15 10:07:41,780] {tf2_trainer.py:72} INFO - train-step 110(epoch=0)  loss:1.9478, accuracy:0.2857 (0.4674 sec/step)
# [2022-02-15 10:07:41,799] {tf2_trainer.py:72} INFO - train-step 111(epoch=0)  loss:1.8879, accuracy:0.3071 (0.0198 sec/step)
# [2022-02-15 10:07:41,815] {tf2_trainer.py:72} INFO - train-step 112(epoch=0)  loss:1.9011, accuracy:0.3286 (0.0154 sec/step)
# [2022-02-15 10:07:41,833] {tf2_trainer.py:72} INFO - train-step 113(epoch=0)  loss:1.9523, accuracy:0.1929 (0.0181 sec/step)
# [2022-02-15 10:07:41,851] {tf2_trainer.py:72} INFO - train-step 114(epoch=0)  loss:1.9129, accuracy:0.2429 (0.0183 sec/step)
# [2022-02-15 10:07:41,869] {tf2_trainer.py:72} INFO - train-step 115(epoch=0)  loss:2.0074, accuracy:0.2500 (0.0178 sec/step)
# [2022-02-15 10:07:41,895] {tf2_trainer.py:72} INFO - train-step 116(epoch=0)  loss:1.8952, accuracy:0.2714 (0.0265 sec/step)
# [2022-02-15 10:07:41,915] {tf2_trainer.py:72} INFO - train-step 117(epoch=0)  loss:1.8654, accuracy:0.2929 (0.0195 sec/step)
# [2022-02-15 10:07:41,936] {tf2_trainer.py:72} INFO - train-step 118(epoch=0)  loss:1.9495, accuracy:0.2214 (0.0211 sec/step)
# [2022-02-15 10:07:41,951] {tf2_trainer.py:72} INFO - train-step 119(epoch=0)  loss:1.9163, accuracy:0.3000 (0.0152 sec/step)
# [2022-02-15 10:07:41,973] {tf2_trainer.py:72} INFO - train-step 120(epoch=0)  loss:1.9420, accuracy:0.2643 (0.0215 sec/step)
# [2022-02-15 10:07:41,989] {tf2_trainer.py:72} INFO - train-step 121(epoch=0)  loss:1.9223, accuracy:0.2357 (0.0164 sec/step)
# [2022-02-15 10:07:42,010] {tf2_trainer.py:72} INFO - train-step 122(epoch=0)  loss:1.8912, accuracy:0.3214 (0.0210 sec/step)
# [2022-02-15 10:07:42,027] {tf2_trainer.py:72} INFO - train-step 123(epoch=0)  loss:1.9554, accuracy:0.2357 (0.0168 sec/step)
# [2022-02-15 10:07:42,053] {tf2_trainer.py:72} INFO - train-step 124(epoch=0)  loss:1.8972, accuracy:0.3000 (0.0264 sec/step)
# [2022-02-15 10:07:42,076] {tf2_trainer.py:72} INFO - train-step 125(epoch=0)  loss:1.9825, accuracy:0.2500 (0.0228 sec/step)
# [2022-02-15 10:07:42,116] {tf2_trainer.py:72} INFO - train-step 126(epoch=0)  loss:1.9814, accuracy:0.2714 (0.0404 sec/step)
# [2022-02-15 10:07:42,142] {tf2_trainer.py:72} INFO - train-step 127(epoch=0)  loss:1.9638, accuracy:0.2929 (0.0260 sec/step)
# [2022-02-15 10:07:42,163] {tf2_trainer.py:72} INFO - train-step 128(epoch=0)  loss:1.9197, accuracy:0.2571 (0.0203 sec/step)
# [2022-02-15 10:07:42,179] {tf2_trainer.py:72} INFO - train-step 129(epoch=0)  loss:1.9648, accuracy:0.2643 (0.0168 sec/step)
# [2022-02-15 10:07:42,200] {tf2_trainer.py:72} INFO - train-step 130(epoch=0)  loss:1.8415, accuracy:0.3500 (0.0205 sec/step)
# [2022-02-15 10:07:42,222] {tf2_trainer.py:72} INFO - train-step 131(epoch=0)  loss:1.8672, accuracy:0.2929 (0.0215 sec/step)
# [2022-02-15 10:07:42,244] {tf2_trainer.py:72} INFO - train-step 132(epoch=0)  loss:1.9429, accuracy:0.2714 (0.0222 sec/step)
# [2022-02-15 10:07:42,264] {tf2_trainer.py:72} INFO - train-step 133(epoch=0)  loss:1.9651, accuracy:0.2571 (0.0201 sec/step)
# [2022-02-15 10:07:42,279] {tf2_trainer.py:72} INFO - train-step 134(epoch=0)  loss:1.9420, accuracy:0.2286 (0.0154 sec/step)
# [2022-02-15 10:07:42,305] {tf2_trainer.py:72} INFO - train-step 135(epoch=0)  loss:1.9421, accuracy:0.3429 (0.0263 sec/step)
# ...
# [2022-02-15 10:07:58,625] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:58,647] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:58,667] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:58,691] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:58,711] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:58,731] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:58,751] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:58,773] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:58,795] {api.py:464} INFO - Att Header: seq(None, 64), seq_flts (None, 7), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 7) ret (None, 7)
# [2022-02-15 10:07:59,485] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:59,507] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:59,532] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:59,568] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:59,591] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:59,619] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:59,642] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:59,662] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:07:59,741] {api.py:464} INFO - Att Header: seq(None, 64), seq_flts (None, 7), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 7) ret (None, 7)
# [2022-02-15 10:08:00,158] {api.py:464} INFO - Att Header: seq(None, 64), seq_flts (None, 7), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 7) ret (None, 7)
# [2022-02-15 10:08:00,271] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:00,311] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:00,356] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:00,411] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:00,447] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:00,488] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:00,537] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:00,599] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:02,019] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:02,052] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:02,080] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:02,109] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:02,132] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:02,157] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:02,185] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:02,207] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:02,232] {api.py:464} INFO - Att Header: seq(None, 64), seq_flts (None, 7), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 7) ret (None, 7)
# [2022-02-15 10:08:02,487] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:02,519] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:02,565] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:02,596] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:02,627] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:02,670] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:02,705] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:02,743] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:02,778] {api.py:464} INFO - Att Header: seq(None, 64), seq_flts (None, 7), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 7) ret (None, 7)
# [2022-02-15 10:08:03,106] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:03,137] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:03,158] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:03,178] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:03,199] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:03,221] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:03,240] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:03,262] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:03,294] {api.py:464} INFO - Att Header: seq(None, 64), seq_flts (None, 7), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 7) ret (None, 7)
# [2022-02-15 10:08:03,545] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:03,577] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:03,607] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:03,654] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:03,685] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:03,718] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:03,749] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:03,780] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:03,815] {api.py:464} INFO - Att Header: seq(None, 64), seq_flts (None, 7), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 7) ret (None, 7)
# [2022-02-15 10:08:04,298] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:04,318] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:04,338] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:04,358] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:04,379] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:04,400] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:04,433] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:04,456] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:04,537] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:04,582] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:04,619] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:04,661] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:04,692] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:04,731] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:04,772] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:04,809] {api.py:464} INFO - Att Header: seq(None, 1433), seq_flts (None, 8), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 8) ret (None, 8)
# [2022-02-15 10:08:04,954] {api.py:464} INFO - Att Header: seq(None, 64), seq_flts (None, 7), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 7) ret (None, 7)
# [2022-02-15 10:08:04,992] {api.py:464} INFO - Att Header: seq(None, 64), seq_flts (None, 7), f_1 (None, 1), f_2 (None, 1), logits (None, 1), coefs <unknown>, vals (None, 7) ret (None, 7)
# WARNING:absl:Found untraced functions such as attn_head_layer_call_and_return_conditional_losses, attn_head_layer_call_fn, attn_head_1_layer_call_and_return_conditional_losses, attn_head_1_layer_call_fn, attn_head_2_layer_call_and_return_conditional_losses while saving (showing 5 of 180). These functions will not be directly callable after loading.
# [2022-02-15 10:08:06,919] {builder_impl.py:775} INFO - Assets written to: tmp/gat_9313790/./ckpt/assets
# [2022-02-15 10:08:07,127] {tf2_trainer.py:257} INFO - training time: 40.576674461364746
# [2022-02-15 10:08:07,129] {logging_utils.py:76} INFO - Training worker finished.

# %%
#!tensorboard --logdir $MODEL_DIR
